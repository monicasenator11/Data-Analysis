# %%
print("Welcome, this is your Virtual Doctor!")
print("\n")

print("What is your name?")
Name = input("Name: ").upper()
print("Nice to meet you,", Name)
print("\n")

print("Please enter your age using integers.")
Age = input("Age: ")
print("\n")


print("Do you have any of these pre-exisiting conditions?:")
print("-Diabetes")
print("-Heart Disease")
print("-Obesity")
print("-Chronic Respiratory Disease")
print("\n")
pre_ex = input("Please type in Yes, or No: ").upper()
print("\n")
        
if pre_ex == "YES":       
    while pre_ex == "YES":
        print("Thank you for providing us with some information about you, this test will ask you some short questions about COVID-19 related symptoms.")
        print("\n")

        print("Do you have a cough?")
        cough = input("Please type in Yes, or No: ").upper()
        print("\n")


        print("Are you experiencing any shortness of breath?")
        sh_breath = input("Please type in Yes, or No: ").upper()
        print("\n")

        print("Have you come in contact with anyone that has tested positive for COVID-19?")
        positive = input("Please type in Yes, or No: ").upper()
        print("\n")

        print("Do you have a fever?")
        fever = input("Please type in Yes, or No: ").upper()
        print("\n")

        print("Are you experiencing any chills?")
        chills = input("Please type in Yes, or No: ").upper()
        print("\n")

        print("Do you have any muscle pain?")
        muscle_pain = input("Please type in Yes, or No: ").upper()
        print("\n")

        print("Do you have a sore throat?")
        soreness = input("Please type in Yes, or No: ").upper()
        print("\n")


        cough = 5
        sh_breath = 5
        positive = 5
        fever = 5
        chills = 5
        muscle_pain = 5
        soreness = 5

        result = cough + sh_breath + positive + fever + chills + muscle_pain + soreness 

        if result >= 15:
            print("Our results indicate that you should seek out a physician for further testing.")
        else: 
            print("No further testing required.")

        break
        

else:
    while pre_ex == "NO":
        print("Thank you for providing us with some information about you, this test will ask you some short questions about COVID-19 related symptoms.")
        print("\n")

        print("Do you have a cough?")
        cough = input("Please type in Yes, or No: ").upper()
        print("\n")


        print("Are you experiencing any shortness of breath?")
        sh_breath = input("Please type in Yes, or No: ").upper()
        print("\n")

        print("Have you come in contact with anyone that has tested positive for COVID-19?")
        positive = input("Please type in Yes, or No: ").upper()
        print("\n")

        print("Do you have a fever?")
        fever = input("Please type in Yes, or No: ").upper()
        print("\n")

        print("Are you experiencing any chills?")
        chills = input("Please type in Yes, or No: ").upper()
        print("\n")

        print("Do you have any muscle pain?")
        muscle_pain = input("Please type in Yes, or No: ").upper()
        print("\n")

        print("Do you have a sore throat?")
        soreness = input("Please type in Yes, or No: ").upper()
        print("\n")


        cough = 5
        sh_breath = 5
        positive = 5
        fever = 5
        chills = 5
        muscle_pain = 5
        soreness = 5


        if result >= 15:
            result = cough + sh_breath + positive + fever + chills + muscle_pain + soreness 
            print("Our results indicate that you should seek out a physician for further testing.")
        else: 
            print("No further testing required.")

        break
# Out:
# Welcome, this is your Virtual Doctor!
#
#
# What is your name?
# Name: monica
# Nice to meet you, MONICA
#
#
# Please enter your age using integers.
# Age: 22
#
#
# Do you have any of these pre-exisiting conditions?:
# -Diabetes
# -Heart Disease
# -Obesity
# -Chronic Respiratory Disease
#
#
# Please type in Yes, or No: yes
#
#
# Thank you for providing us with some information about you, this test will ask you some short questions about COVID-19 related symptoms.
#
#
# Do you have a cough?
# Please type in Yes, or No: no
#
#
# Are you experiencing any shortness of breath?
# Please type in Yes, or No: no
#
#
# Have you come in contact with anyone that has tested positive for COVID-19?
# Please type in Yes, or No: no
#
#
# Do you have a fever?
# Please type in Yes, or No: no
#
#
# Are you experiencing any chills?
# Please type in Yes, or No: no
#
#
# Do you have any muscle pain?
# Please type in Yes, or No: no
#
#
# Do you have a sore throat?
# Please type in Yes, or No: no
#
#
# ...
